# %%
import pandas as pd

# %%
zips = ('Raw Data/zipPopDensity_meanHHI.csv')

zips_df=pd.read_csv(zips)
zips_df
# Out:
#      ZIP_CODE        PO_NAME STATE  zipCodePop  areaSqMile   PopDensity  \
# 0       97212       Portland    OR       26991       2.775  9726.486486
# 1       97206       Portland    OR       50943       6.417  7938.756428
# 2       97213       Portland    OR       31777       4.092  7765.640274
# 3       97215       Portland    OR       17376       2.365  7347.145877
# 4       97227       Portland    OR        8113       1.126  7205.150977
# ..        ...            ...   ...         ...         ...          ...
# 278     97627           Keno    OR         650     701.142     0.927059
# 279     97750       Mitchell    OR         845     949.083     0.890333
# 280     97739        La Pine    OR        1201    1485.296     0.808593
# 281     97037         Maupin    OR         710     945.902     0.750606
# 282     97910  Jordan Valley    OR         756    4651.573     0.162526
#
#        MeaHHI
# 0    146186.0
# 1     87404.0
# 2    104868.0
# 3    112734.0
# 4    109494.0
# ...

# %%
zips_df = zips_df.drop(['PO_NAME','STATE','zipCodePop','areaSqMile'], axis=1)

# %%
zips_df = zips_df.set_index('ZIP_CODE')
zips_df
# Out:
#            PopDensity    MeaHHI
# ZIP_CODE
# 97212     9726.486486  146186.0
# 97206     7938.756428   87404.0
# 97213     7765.640274  104868.0
# 97215     7347.145877  112734.0
# 97227     7205.150977  109494.0
# ...               ...       ...
# 97627        0.927059   69569.0
# 97750        0.890333   55531.0
# 97739        0.808593   60857.0
# 97037        0.750606   66820.0
# 97910        0.162526   56393.0
#
# [283 rows x 2 columns]

# %%
zips_df.to_dict('index')
# Out:
# {97212: {'PopDensity': 9726.486486, 'MeaHHI': 146186.0},
#  97206: {'PopDensity': 7938.756428, 'MeaHHI': 87404.0},
#  97213: {'PopDensity': 7765.640274, 'MeaHHI': 104868.0},
#  97215: {'PopDensity': 7347.145877, 'MeaHHI': 112734.0},
#  97227: {'PopDensity': 7205.150977, 'MeaHHI': 109494.0},
#  97214: {'PopDensity': 5613.333333, 'MeaHHI': 96678.0},
#  97211: {'PopDensity': 4738.850772, 'MeaHHI': 107669.0},
#  97027: {'PopDensity': 4579.968944, 'MeaHHI': 92998.0},
#  97232: {'PopDensity': 4091.906005, 'MeaHHI': 87464.0},
#  97267: {'PopDensity': 3968.144232, 'MeaHHI': 85929.0},
#  97003: {'PopDensity': 3869.983278, 'MeaHHI': nan},
#  97202: {'PopDensity': 3399.439851, 'MeaHHI': 113578.0},
#  97035: {'PopDensity': 3373.416653, 'MeaHHI': 140650.0},
#  97223: {'PopDensity': 3337.700683, 'MeaHHI': 104461.0},
#  97222: {'PopDensity': 3306.249306, 'MeaHHI': 79481.0},
#  97216: {'PopDensity': 3211.941479, 'MeaHHI': 70982.0},
#  97201: {'PopDensity': 3201.877934, 'MeaHHI': 101606.0},
# ...
